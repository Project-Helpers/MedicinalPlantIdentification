# %% [markdown]
# <a href="https://colab.research.google.com/github/AusafMo/NoteBook-Medicinal-Herb-Model-ResNet/blob/main/Medicinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/medicinal/leaf.zip', 'r') # Opens the zip file in read mode
zip_ref.extractall('/leaf') #Extracts the files into the /tmp folder
zip_ref.close()

# %%
import torch
from collections import Counter
import pandas as pd
import plotly.express as px
from sklearn.model_selection import train_test_split
import os
from glob import glob
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# Data science tools
import numpy as np
import pandas as pd
import os

# Image manipulations
from PIL import Image

from timeit import default_timer as timer

# Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.size'] = 14

# %% [markdown]
# ---
# # **Importing Files**
# Restructering and Renaming Directories
# ---

# %%
ImagePATH = f"/leaf/"

# %%
from glob import glob
types = glob(ImagePATH+"*")

# %%
print(types)
# Out:
# ['/leaf/Piper Betle (Betel)', '/leaf/Alpinia Galanga (Rasna)', '/leaf/Hibiscus Rosa-sinensis', '/leaf/Mangifera Indica (Mango)', '/leaf/Murraya Koenigii (Curry)', '/leaf/Basella Alba (Basale)', '/leaf/Brassica Juncea (Indian Mustard)', '/leaf/Citrus Limon (Lemon)', '/leaf/Psidium Guajava (Guava)', '/leaf/Moringa Oleifera (Drumstick)', '/leaf/Trigonella Foenum-graecum (Fenugreek)', '/leaf/Nerium Oleander (Oleander)', '/leaf/Pongamia Pinnata (Indian Beech)', '/leaf/Ocimum Tenuiflorum (Tulsi)', '/leaf/Muntingia Calabura (Jamaica Cherry-Gasagase)', '/leaf/Amaranthus Viridis (Arive-Dantu)', '/leaf/Plectranthus Amboinicus (Mexican Mint)', '/leaf/Syzygium Cumini (Jamun)', '/leaf/Azadirachta Indica (Neem)', '/leaf/Tabernaemontana Divaricata (Crape Jasmine)', '/leaf/Nyctanthes Arbor-tristis (Parijata)', '/leaf/Ficus Auriculata (Roxburgh fig)', '/leaf/Santalum Album (Sandalwood)', '/leaf/Jasminum (Jasmine)', '/leaf/Syzygium Jambos (Rose Apple)', '/leaf/Artocarpus Heterophyllus (Jackfruit)', '/leaf/Ficus Religiosa (Peepal Tree)', '/leaf/Punica Granatum (Pomegranate)', '/leaf/Carissa Carandas (Karanda)', '/leaf/Mentha (Mint)']

# %%
# Making DATAFRAME

filedf = pd.DataFrame()
for typ in types:
    files = glob(typ + "/*" )
    tempdf = pd.DataFrame( { 'filepath' : files, 'types':typ.split("/")[-1]} )
    filedf = pd.concat( [ filedf, tempdf ] )

# %%
print(filedf)
# Out:
#                                   filepath                types
# 0   /leaf/Piper Betle (Betel)/PB-S-026.jpg  Piper Betle (Betel)
# 1   /leaf/Piper Betle (Betel)/PB-S-024.jpg  Piper Betle (Betel)
# 2   /leaf/Piper Betle (Betel)/PB-S-048.jpg  Piper Betle (Betel)
# 3   /leaf/Piper Betle (Betel)/PB-S-023.jpg  Piper Betle (Betel)
# 4   /leaf/Piper Betle (Betel)/PB-S-004.jpg  Piper Betle (Betel)
# ..                                     ...                  ...
# 92         /leaf/Mentha (Mint)/M-S-037.jpg        Mentha (Mint)
# 93         /leaf/Mentha (Mint)/M-S-089.jpg        Mentha (Mint)
# 94         /leaf/Mentha (Mint)/M-S-061.jpg        Mentha (Mint)
# 95         /leaf/Mentha (Mint)/M-S-046.jpg        Mentha (Mint)
# 96         /leaf/Mentha (Mint)/M-S-067.jpg        Mentha (Mint)
#
# [1835 rows x 2 columns]

# %% [markdown]
# ### ***Grouping the types and arranging them by their count ( number of samples )***

# %%
gby_cnt = filedf.groupby( "types" ).aggregate( 'count' ).rename( columns = {'filepath' : 'cnt' } ).reset_index().sort_values( by = 'cnt', ascending = False )

# %%
gby_cnt
# Out:
#                                            types  cnt
# 1               Amaranthus Viridis (Arive-Dantu)  122
# 4                          Basella Alba (Basale)  103
# 13                                 Mentha (Mint)   97
# 24                 Punica Granatum (Pomegranate)   79
# 14                  Moringa Oleifera (Drumstick)   77
# 6                     Carissa Carandas (Karanda)   74
# 11                            Jasminum (Jasmine)   71
# 23                       Psidium Guajava (Guava)   65
# 9                  Ficus Religiosa (Peepal Tree)   63
# 17                    Nerium Oleander (Oleander)   62
# 12                      Mangifera Indica (Mango)   62
# 22               Pongamia Pinnata (Indian Beech)   61
# 3                      Azadirachta Indica (Neem)   60
# 16                      Murraya Koenigii (Curry)   60
# 25                   Santalum Album (Sandalwood)   58
# 7                           Citrus Limon (Lemon)   57
# 27                  Syzygium Jambos (Rose Apple)   56
# 28    Tabernaemontana Divaricata (Crape Jasmine)   56
# 2           Artocarpus Heterophyllus (Jackfruit)   56
# 15  Muntingia Calabura (Jamaica Cherry-Gasagase)   56
# 19                    Ocimum Tenuiflorum (Tulsi)   52
# 0                        Alpinia Galanga (Rasna)   50
# 8                Ficus Auriculata (Roxburgh fig)   50
# 21        Plectranthus Amboinicus (Mexican Mint)   48
# 20                           Piper Betle (Betel)   48
# 10                        Hibiscus Rosa-sinensis   43
# 18           Nyctanthes Arbor-tristis (Parijata)   40
# 26                       Syzygium Cumini (Jamun)   39
# 29         Trigonella Foenum-graecum (Fenugreek)   36
# 5               Brassica Juncea (Indian Mustard)   34

# %%
fig = px.bar( gby_cnt, x = 'types', y = 'cnt', color = 'types', title = 'Counts from Each Types')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1bef8e53-c636-4d69-af82-b72a53605b51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bef8e53-c636-4d69-af82-b72a53605b51")) {                    Plotly.newPlot(                        "1bef8e53-c636-4d69-af82-b72a53605b51",                        [{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amaranthus Viridis (Arive-Dantu)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Amaranthus Viridis (Arive-Dantu)","offsetgroup":"Amaranthus Viridis (Arive-Dantu)","orientation":"v","showlegend":true,"textposition":"auto","x":["Amaranthus Viridis (Arive-Dantu)"],"xaxis":"x","y":[122],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Basella Alba (Basale)","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Basella Alba (Basale)","offsetgroup":"Basella Alba (Basale)","orientation":"v","showlegend":true,"textposition":"auto","x":["Basella Alba (Basale)"],"xaxis":"x","y":[103],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mentha (Mint)","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Mentha (Mint)","offsetgroup":"Mentha (Mint)","orientation":"v","showlegend":true,"textposition":"auto","x":["Mentha (Mint)"],"xaxis":"x","y":[97],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Punica Granatum (Pomegranate)","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Punica Granatum (Pomegranate)","offsetgroup":"Punica Granatum (Pomegranate)","orientation":"v","showlegend":true,"textposition":"auto","x":["Punica Granatum (Pomegranate)"],"xaxis":"x","y":[79],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Moringa Oleifera (Drumstick)","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Moringa Oleifera (Drumstick)","offsetgroup":"Moringa Oleifera (Drumstick)","orientation":"v","showlegend":true,"textposition":"auto","x":["Moringa Oleifera (Drumstick)"],"xaxis":"x","y":[77],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Carissa Carandas (Karanda)","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Carissa Carandas (Karanda)","offsetgroup":"Carissa Carandas (Karanda)","orientation":"v","showlegend":true,"textposition":"auto","x":["Carissa Carandas (Karanda)"],"xaxis":"x","y":[74],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Jasminum (Jasmine)","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Jasminum (Jasmine)","offsetgroup":"Jasminum (Jasmine)","orientation":"v","showlegend":true,"textposition":"auto","x":["Jasminum (Jasmine)"],"xaxis":"x","y":[71],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Psidium Guajava (Guava)","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Psidium Guajava (Guava)","offsetgroup":"Psidium Guajava (Guava)","orientation":"v","showlegend":true,"textposition":"auto","x":["Psidium Guajava (Guava)"],"xaxis":"x","y":[65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"types=%{x}\u003cbr\u003e ...

# %%
# !mkdir outputs

# %%
gby_cnt.to_csv(f"outputs/types_counts.csv", index = None )

# %% [markdown]
# # **Checking Some Data Samples**

# %%
plt.figure( figsize = ( 20, 20 ) )

for i in range(10):

    path = filedf.sample( 1 )['filepath'].values[0]
    types = path.split( "/" )[2]
    ex_img = Image.open(path)
    ax = plt.subplot( 4, 4, i + 1 )
    ax.annotate( types, xy = ( 0.1, 0.9 ), xycoords = " axes fraction ", weight = 'light', size = 10 )
    ax.imshow(ex_img)

plt.show()

# %% [markdown]
# # **Splitting the DataSet into Train Test Split**

# %%
print("dataframe length:", len(filedf))

print(filedf.types.value_counts().head(10))

print("total samples: ", filedf.types.value_counts().sum())
# Out:
# dataframe length: 1835
# Amaranthus Viridis (Arive-Dantu)    122
# Basella Alba (Basale)               103
# Mentha (Mint)                        97
# Punica Granatum (Pomegranate)        79
# Moringa Oleifera (Drumstick)         77
# Carissa Carandas (Karanda)           74
# Jasminum (Jasmine)                   71
# Psidium Guajava (Guava)              65
# Ficus Religiosa (Peepal Tree)        63
# Mangifera Indica (Mango)             62
# Name: types, dtype: int64
# total samples:  1835

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
        filedf, filedf['types'], stratify = filedf['types'], test_size=0.4)

X_test, X_val, Y_test, Y_val = train_test_split(
        X_test, X_test['types'], stratify = X_test['types'], test_size=0.5)

# %%
X_train
# Out:
#                                              filepath  \
# 49                    /leaf/Mentha (Mint)/M-S-045.jpg
# 25          /leaf/Hibiscus Rosa-sinensis/HR-S-016.jpg
# 34  /leaf/Nyctanthes Arbor-tristis (Parijata)/NA-S...
# 28                    /leaf/Mentha (Mint)/M-S-090.jpg
# 8                     /leaf/Mentha (Mint)/M-S-032.jpg
# ..                                                ...
# 32  /leaf/Amaranthus Viridis (Arive-Dantu)/AV-S-09...
# 24  /leaf/Brassica Juncea (Indian Mustard)/BJ-S-02...
# 19             /leaf/Piper Betle (Betel)/PB-S-044.jpg
# 45    /leaf/Syzygium Jambos (Rose Apple)/SJ-S-013.jpg
# 42  /leaf/Ficus Auriculata (Roxburgh fig)/FA-S-011...
#
#                                   types
# 49                        Mentha (Mint)
# 25               Hibiscus Rosa-sinensis
# 34  Nyctanthes Arbor-tristis (Parijata)
# 28                        Mentha (Mint)
# 8                         Mentha (Mint)
# ..                                  ...
# 32     Amaranthus Viridis (Arive-Dantu)
# 24     Brassica Juncea (Indian Mustard)
# 19                  Piper Betle (Betel)
# 45         Syzygium Jambos (Rose Apple)
# 42      Ficus Auriculata (Roxburgh fig)
#
# [1101 rows x 2 columns]

# %%
X_test
# Out:
#                                              filepath  \
# 45       /leaf/Azadirachta Indica (Neem)/AI-S-025.jpg
# 54  /leaf/Amaranthus Viridis (Arive-Dantu)/AV-S-03...
# 44    /leaf/Moringa Oleifera (Drumstick)/MO-S-036.jpg
# 51            /leaf/Citrus Limon (Lemon)/CL-S-024.jpg
# 6         /leaf/Mangifera Indica (Mango)/MI-S-058.jpg
# ..                                                ...
# 43             /leaf/Piper Betle (Betel)/PB-S-031.jpg
# 8           /leaf/Hibiscus Rosa-sinensis/HR-S-041.jpg
# 53  /leaf/Artocarpus Heterophyllus (Jackfruit)/AH-...
# 25               /leaf/Jasminum (Jasmine)/J-S-047.jpg
# 43  /leaf/Amaranthus Viridis (Arive-Dantu)/AV-S-12...
#
#                                    types
# 45             Azadirachta Indica (Neem)
# 54      Amaranthus Viridis (Arive-Dantu)
# 44          Moringa Oleifera (Drumstick)
# 51                  Citrus Limon (Lemon)
# 6               Mangifera Indica (Mango)
# ..                                   ...
# 43                   Piper Betle (Betel)
# 8                 Hibiscus Rosa-sinensis
# 53  Artocarpus Heterophyllus (Jackfruit)
# 25                    Jasminum (Jasmine)
# 43      Amaranthus Viridis (Arive-Dantu)
#
# [367 rows x 2 columns]

# %%
Y_train
# Out:
# 49                          Mentha (Mint)
# 25                 Hibiscus Rosa-sinensis
# 34    Nyctanthes Arbor-tristis (Parijata)
# 28                          Mentha (Mint)
# 8                           Mentha (Mint)
#                      ...
# 32       Amaranthus Viridis (Arive-Dantu)
# 24       Brassica Juncea (Indian Mustard)
# 19                    Piper Betle (Betel)
# 45           Syzygium Jambos (Rose Apple)
# 42        Ficus Auriculata (Roxburgh fig)
# Name: types, Length: 1101, dtype: object

# %%
Y_test
# Out:
# 45               Azadirachta Indica (Neem)
# 54        Amaranthus Viridis (Arive-Dantu)
# 44            Moringa Oleifera (Drumstick)
# 51                    Citrus Limon (Lemon)
# 6                 Mangifera Indica (Mango)
#                       ...
# 43                     Piper Betle (Betel)
# 8                   Hibiscus Rosa-sinensis
# 53    Artocarpus Heterophyllus (Jackfruit)
# 25                      Jasminum (Jasmine)
# 43        Amaranthus Viridis (Arive-Dantu)
# Name: types, Length: 367, dtype: object

# %%
X_val
# Out:
#                                              filepath  \
# 7   /leaf/Amaranthus Viridis (Arive-Dantu)/AV-S-02...
# 26    /leaf/Syzygium Jambos (Rose Apple)/SJ-S-009.jpg
# 31  /leaf/Tabernaemontana Divaricata (Crape Jasmin...
# 27  /leaf/Tabernaemontana Divaricata (Crape Jasmin...
# 33          /leaf/Hibiscus Rosa-sinensis/HR-S-029.jpg
# ..                                                ...
# 10  /leaf/Tabernaemontana Divaricata (Crape Jasmin...
# 17   /leaf/Punica Granatum (Pomegranate)/PG-S-063.jpg
# 38  /leaf/Amaranthus Viridis (Arive-Dantu)/AV-S-09...
# 32    /leaf/Moringa Oleifera (Drumstick)/MO-S-032.jpg
# 3            /leaf/Basella Alba (Basale)/BA-S-020.jpg
#
#                                          types
# 7             Amaranthus Viridis (Arive-Dantu)
# 26                Syzygium Jambos (Rose Apple)
# 31  Tabernaemontana Divaricata (Crape Jasmine)
# 27  Tabernaemontana Divaricata (Crape Jasmine)
# 33                      Hibiscus Rosa-sinensis
# ..                                         ...
# 10  Tabernaemontana Divaricata (Crape Jasmine)
# 17               Punica Granatum (Pomegranate)
# 38            Amaranthus Viridis (Arive-Dantu)
# 32                Moringa Oleifera (Drumstick)
# 3                        Basella Alba (Basale)
#
# [367 rows x 2 columns]

# %%
Y_val
# Out:
# 7               Amaranthus Viridis (Arive-Dantu)
# 26                  Syzygium Jambos (Rose Apple)
# 31    Tabernaemontana Divaricata (Crape Jasmine)
# 27    Tabernaemontana Divaricata (Crape Jasmine)
# 33                        Hibiscus Rosa-sinensis
#                          ...
# 10    Tabernaemontana Divaricata (Crape Jasmine)
# 17                 Punica Granatum (Pomegranate)
# 38              Amaranthus Viridis (Arive-Dantu)
# 32                  Moringa Oleifera (Drumstick)
# 3                          Basella Alba (Basale)
# Name: types, Length: 367, dtype: object

# %%
X_train['use'] = 'train'
X_val['use'] = 'val'
X_test['use'] = 'test'

# %%
fulldf = pd.concat([ X_train, X_test, X_val ])

# %%
fulldf.use.value_counts()
# Out:
# train    1101
# test      367
# val       367
# Name: use, dtype: int64

# %% [markdown]
# #### Final DATFRAME

# %%
fulldf.head(20)
# Out:
#                                              filepath  \
# 49                    /leaf/Mentha (Mint)/M-S-045.jpg
# 25          /leaf/Hibiscus Rosa-sinensis/HR-S-016.jpg
# 34  /leaf/Nyctanthes Arbor-tristis (Parijata)/NA-S...
# 28                    /leaf/Mentha (Mint)/M-S-090.jpg
# 8                     /leaf/Mentha (Mint)/M-S-032.jpg
# 48        /leaf/Mangifera Indica (Mango)/MI-S-041.jpg
# 42  /leaf/Pongamia Pinnata (Indian Beech)/PP-S-039...
# 12  /leaf/Plectranthus Amboinicus (Mexican Mint)/P...
# 11  /leaf/Ficus Auriculata (Roxburgh fig)/FA-S-022...
# 48      /leaf/Ocimum Tenuiflorum (Tulsi)/OT-S-024.jpg
# 11        /leaf/Murraya Koenigii (Curry)/MK-S-031.jpg
# 21      /leaf/Carissa Carandas (Karanda)/CC-S-065.jpg
# 28       /leaf/Azadirachta Indica (Neem)/AI-S-034.jpg
# 0     /leaf/Moringa Oleifera (Drumstick)/MO-S-064.jpg
# 21         /leaf/Alpinia Galanga (Rasna)/AG-S-043.jpg
# 31  /leaf/Artocarpus Heterophyllus (Jackfruit)/AH-...
# 41             /leaf/Piper Betle (Betel)/PB-S-036.jpg
# 0       /leaf/Nerium Oleander (Oleander)/NO-S-025.jpg
# 39               /leaf/Jasminum (Jasmine)/J-S-035.jpg
# 33  /leaf/Ficus Auriculata (Roxburgh fig)/FA-S-041...
#
#                                      types    use
# 49                           Mentha (Mint)  train
# 25                  Hibiscus Rosa-sinensis  train
# 34     Nyctanthes Arbor-tristis (Parijata)  train
# 28                           Mentha (Mint)  train
# 8                            Mentha (Mint)  train
# 48                Mangifera Indica (Mango)  train
# 42         Pongamia Pinnata (Indian Beech)  train
# 12  Plectranthus Amboinicus (Mexican Mint)  train
# 11         Ficus Auriculata (Roxburgh fig)  train
# 48              Ocimum Tenuiflorum (Tulsi)  train
# 11                Murraya Koenigii (Curry)  train
# 21              Carissa Carandas (Karanda)  train
# 28               Azadirachta Indica (Neem)  train
# 0             Moringa Oleifera (Drumstick)  train
# 21                 Alpinia Galanga (Rasna)  train
# 31    Artocarpus Heterophyllus (Jackfruit)  train
# 41                     Piper Betle (Betel)  train
# 0               Nerium Oleander (Oleander)  train
# 39                      Jasminum (Jasmine)  train
# 33         Ficus Auriculata (Roxburgh fig)  train

# %% [markdown]
# ##### BASELINE ACCURACY

# %%
fulldf.types.value_counts()[0] / len( fulldf ) ## basically which sample dominates
# Out:
# 0.0664850136239782

# %% [markdown]
# ### **Creating Train, Test, Validation Folders**

# %%
# !mkdir data
# !rm -rf data/
# !rm -rf data/train
# !rm -rf data/test
# !rm -rf data/val
# !mkdir data/
# !mkdir data/train
# !mkdir data/test
# !mkdir data/val

# %%
fulldf.types.unique()
# Out:
# array(['Mentha (Mint)', 'Hibiscus Rosa-sinensis',
#        'Nyctanthes Arbor-tristis (Parijata)', 'Mangifera Indica (Mango)',
#        'Pongamia Pinnata (Indian Beech)',
#        'Plectranthus Amboinicus (Mexican Mint)',
#        'Ficus Auriculata (Roxburgh fig)', 'Ocimum Tenuiflorum (Tulsi)',
#        'Murraya Koenigii (Curry)', 'Carissa Carandas (Karanda)',
#        'Azadirachta Indica (Neem)', 'Moringa Oleifera (Drumstick)',
#        'Alpinia Galanga (Rasna)', 'Artocarpus Heterophyllus (Jackfruit)',
#        'Piper Betle (Betel)', 'Nerium Oleander (Oleander)',
#        'Jasminum (Jasmine)', 'Psidium Guajava (Guava)',
#        'Brassica Juncea (Indian Mustard)', 'Basella Alba (Basale)',
#        'Ficus Religiosa (Peepal Tree)', 'Punica Granatum (Pomegranate)',
#        'Amaranthus Viridis (Arive-Dantu)', 'Syzygium Jambos (Rose Apple)',
#        'Citrus Limon (Lemon)', 'Syzygium Cumini (Jamun)',
#        'Santalum Album (Sandalwood)',
#        'Muntingia Calabura (Jamaica Cherry-Gasagase)',
#        'Trigonella Foenum-graecum (Fenugreek)',
#        'Tabernaemontana Divaricata (Crape Jasmine)'], dtype=object)

# %%
for typ in fulldf.types.unique():
    os.system(f"mkdir data/train/'{typ}'")
    os.system(f"mkdir data/test/'{typ}'")
    os.system(f"mkdir data/val/'{typ}'")

# %%
fulldf.head()
# Out:
#                                              filepath  \
# 49                    /leaf/Mentha (Mint)/M-S-045.jpg
# 25          /leaf/Hibiscus Rosa-sinensis/HR-S-016.jpg
# 34  /leaf/Nyctanthes Arbor-tristis (Parijata)/NA-S...
# 28                    /leaf/Mentha (Mint)/M-S-090.jpg
# 8                     /leaf/Mentha (Mint)/M-S-032.jpg
#
#                                   types    use
# 49                        Mentha (Mint)  train
# 25               Hibiscus Rosa-sinensis  train
# 34  Nyctanthes Arbor-tristis (Parijata)  train
# 28                        Mentha (Mint)  train
# 8                         Mentha (Mint)  train

# %%
for i, row in fulldf.iterrows():

    # plant category
    typ = row['types']

    # section is train,val or test
    section = row['use']

    # input filepath to copy
    ipath = row['filepath']

    # output filepath to paste
    opath = ipath.replace(f"/leaf/",f"data/{section}/")


    # running the cp command
    os.system(f"cp '{ipath}' '{opath}'")

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ### **Transforms**
# In order to use our images with a network trained on the Imagenet dataset, we need to preprocess our images in the same way as the Imagenet network. For that, we need to rescale the images to 224×224 and normalize them as per Imagenet standards. We can use the torchvision transforms library to do that. Here we take a CenterCrop of 224×224 and normalize as per Imagenet standards.

# %% [markdown]
# # **PLANT MODEL**

# %%
import torch
from collections import Counter
import pandas as pd
import plotly.express as px
from sklearn.model_selection import train_test_split
import os
from glob import glob
from torchvision import transforms
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision import models
import torch.nn as nn

from torchvision import transforms, datasets, models
import torch
from torch import optim, cuda
from torch.utils.data import DataLoader, sampler
import torch.nn as nn
import numpy as np
import tqdm

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# Data science tools
import numpy as np
import pandas as pd
import os

# Image manipulations
from PIL import Image

from timeit import default_timer as timer

# Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.size'] = 14

# %%
from torch import Tensor, nn
from torch.nn.functional import interpolate

# %%
def imshow_tensor(image, ax=None, title=None):
    """Imshow for Tensor."""

    if ax is None:
        fig, ax = plt.subplots()

    # Set the color channel as the third dimension
    image = image.numpy().transpose((1, 2, 0))

    # Reverse the preprocessing steps
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    # Clip the image pixel values
    image = np.clip(image, 0, 1)

    ax.imshow(image)
    plt.axis('off')

    return ax, image

# %%
traindir = f"data/train"
validdir = f"data/val"
testdir = f"data/test"

# %%
os.listdir('data/train/')
# Out:
# ['Piper Betle (Betel)',
#  'Alpinia Galanga (Rasna)',
#  'Hibiscus Rosa-sinensis',
#  'Mangifera Indica (Mango)',
#  'Murraya Koenigii (Curry)',
#  'Basella Alba (Basale)',
#  'Brassica Juncea (Indian Mustard)',
#  'Citrus Limon (Lemon)',
#  'Psidium Guajava (Guava)',
#  'Moringa Oleifera (Drumstick)',
#  'Trigonella Foenum-graecum (Fenugreek)',
#  'Nerium Oleander (Oleander)',
#  'Pongamia Pinnata (Indian Beech)',
#  'Ocimum Tenuiflorum (Tulsi)',
#  'Muntingia Calabura (Jamaica Cherry-Gasagase)',
#  'Amaranthus Viridis (Arive-Dantu)',
#  'Plectranthus Amboinicus (Mexican Mint)',
#  'Syzygium Cumini (Jamun)',
#  'Azadirachta Indica (Neem)',
#  'Tabernaemontana Divaricata (Crape Jasmine)',
#  'Nyctanthes Arbor-tristis (Parijata)',
#  'Ficus Auriculata (Roxburgh fig)',
#  'Santalum Album (Sandalwood)',
#  'Jasminum (Jasmine)',
#  'Syzygium Jambos (Rose Apple)',
#  'Artocarpus Heterophyllus (Jackfruit)',
#  'Ficus Religiosa (Peepal Tree)',
#  'Punica Granatum (Pomegranate)',
#  'Carissa Carandas (Karanda)',
#  'Mentha (Mint)']

# %%
save_file_name = f'resnet50-transfer.pt'
checkpoint_path = f'resnet50-transfer.pth'

# Change to fit hardware
batch_size = 512
###### MINE
multi_gpu = False
# Whether to train on a gpu
train_on_gpu = cuda.is_available()
print(f'Train on gpu: {train_on_gpu}')

# Number of gpus
if train_on_gpu:
    gpu_count = cuda.device_count()
    print(f'{gpu_count} gpus detected.')
    if gpu_count > 1:
        multi_gpu = True
    else:
        multi_gpu = False
print(train_on_gpu,multi_gpu)
# Out:
# Train on gpu: True
# 1 gpus detected.
# True False

# %%
image_transforms = {
    # Train uses data augmentation
    'train':
    transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.ColorJitter(),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),  # Image net standards
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])  # Imagenet standards
    ]),
    # Validation does not use augmentation
    'valid':
    transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),

        # Test does not use augmentation
    'test':
    transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
ex_img = Image.open('/content/data/train/Alpinia Galanga (Rasna)/AG-S-001.jpg')

t = image_transforms['train']
plt.figure(figsize=(10, 10))

for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    _ = imshow_tensor(t(ex_img), ax=ax)

plt.tight_layout()

# %% [markdown]
# # **DATALOADER**

# %%
# Datasets from folders
data = {
    'train':
    datasets.ImageFolder( root = traindir, transform = image_transforms['train'] ),
    'valid':
    datasets.ImageFolder( root = validdir, transform = image_transforms['valid']),
    'test':
    datasets.ImageFolder( root = testdir, transform = image_transforms['test'])
}

# Dataloader iterators, make sure to shuffle
dataloaders = {
    'train': DataLoader( data['train'], batch_size = batch_size, shuffle = True, num_workers = 0 ),
    'val': DataLoader( data['valid'], batch_size = batch_size, shuffle = True, num_workers = 0),
    'test': DataLoader( data['test'], batch_size = batch_size, shuffle = True, num_workers= 0)
}

# %%
# Iterate through the dataloader once
trainiter = iter(dataloaders['train'])
features, labels = next(trainiter)
features.shape, labels.shape
# Out:
# (torch.Size([512, 3, 224, 224]), torch.Size([512]))

# %%
categories = []
for d in os.listdir(traindir):
    categories.append(d)

n_classes = len(categories)
print(f'There are {n_classes} different classes.')
# Out:
# There are 30 different classes.

# %% [markdown]
# # **Some Statistics**

# %%
class_to_idx = data['train'].class_to_idx
idx_to_class = {
    idx: class_
    for class_, idx in data['train'].class_to_idx.items()
}

# %%
train_cnts = Counter([idx_to_class[x] for x in data['train'].targets])
val_cnts = Counter([idx_to_class[x] for x in data['valid'].targets])
test_cnts = Counter([idx_to_class[x] for x in data['test'].targets])

# %%
train_cnts = pd.DataFrame({'cat' :list(train_cnts.keys()), 'train_cnt': list(train_cnts.values())})
val_cnts = pd.DataFrame({'cat' :list(val_cnts.keys()), 'val_cnt': list(val_cnts.values())})
test_cnts = pd.DataFrame({'cat' :list(test_cnts.keys()), 'test_cnt': list(test_cnts.values())})

# %%
cnt_df = pd.merge(train_cnts,val_cnts,on='cat',how='left').merge(test_cnts,on='cat',how='left')

# %%
cnt_df.head()
# Out:
#                                     cat  train_cnt  val_cnt  test_cnt
# 0               Alpinia Galanga (Rasna)         30       10        10
# 1      Amaranthus Viridis (Arive-Dantu)         73       25        24
# 2  Artocarpus Heterophyllus (Jackfruit)         33       11        12
# 3             Azadirachta Indica (Neem)         36       12        12
# 4                 Basella Alba (Basale)         62       21        20

# %%
idx_to_class
# Out:
# {0: 'Alpinia Galanga (Rasna)',
#  1: 'Amaranthus Viridis (Arive-Dantu)',
#  2: 'Artocarpus Heterophyllus (Jackfruit)',
#  3: 'Azadirachta Indica (Neem)',
#  4: 'Basella Alba (Basale)',
#  5: 'Brassica Juncea (Indian Mustard)',
#  6: 'Carissa Carandas (Karanda)',
#  7: 'Citrus Limon (Lemon)',
#  8: 'Ficus Auriculata (Roxburgh fig)',
#  9: 'Ficus Religiosa (Peepal Tree)',
#  10: 'Hibiscus Rosa-sinensis',
#  11: 'Jasminum (Jasmine)',
#  12: 'Mangifera Indica (Mango)',
#  13: 'Mentha (Mint)',
#  14: 'Moringa Oleifera (Drumstick)',
#  15: 'Muntingia Calabura (Jamaica Cherry-Gasagase)',
#  16: 'Murraya Koenigii (Curry)',
#  17: 'Nerium Oleander (Oleander)',
#  18: 'Nyctanthes Arbor-tristis (Parijata)',
#  19: 'Ocimum Tenuiflorum (Tulsi)',
#  20: 'Piper Betle (Betel)',
#  21: 'Plectranthus Amboinicus (Mexican Mint)',
#  22: 'Pongamia Pinnata (Indian Beech)',
#  23: 'Psidium Guajava (Guava)',
#  24: 'Punica Granatum (Pomegranate)',
#  25: 'Santalum Album (Sandalwood)',
#  26: 'Syzygium Cumini (Jamun)',
#  27: 'Syzygium Jambos (Rose Apple)',
#  28: 'Tabernaemontana Divaricata (Crape Jasmine)',
#  29: 'Trigonella Foenum-graecum (Fenugreek)'}

# %% [markdown]
# # **MODELS**

# %%
model = models.resnet50( weights = 'DEFAULT' )
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 148MB/s]

# %%
# Freeze model weights
for param in model.parameters():
    param.requires_grad = False

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
n_inputs = model.fc.in_features

# %%
model.fc = nn.Sequential(
                      nn.Linear(n_inputs, 256),
                      nn.ReLU(),
                      nn.Dropout(0.4),
                      nn.Linear(256, n_classes),
                      nn.LogSoftmax(dim=1))

# %%
model.fc
# Out:
# Sequential(
#   (0): Linear(in_features=2048, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.4, inplace=False)
#   (3): Linear(in_features=256, out_features=30, bias=True)
#   (4): LogSoftmax(dim=1)
# )

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} training parameters.')
# Out:
# 24,040,286 total parameters.
# 532,254 training parameters.

# %%
if train_on_gpu:
    model = model.to('cuda')

if multi_gpu:
    model = nn.DataParallel(model)

# %%
if multi_gpu:
    print(model.module.fc)
else:
    print(model.fc)
# Out:
# Sequential(
#   (0): Linear(in_features=2048, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.4, inplace=False)
#   (3): Linear(in_features=256, out_features=30, bias=True)
#   (4): LogSoftmax(dim=1)
# )

# %%
model.class_to_idx = data['train'].class_to_idx
model.idx_to_class = {
    idx: class_
    for class_, idx in model.class_to_idx.items()
}

list(model.idx_to_class.items())
# Out:
# [(0, 'Alpinia Galanga (Rasna)'),
#  (1, 'Amaranthus Viridis (Arive-Dantu)'),
#  (2, 'Artocarpus Heterophyllus (Jackfruit)'),
#  (3, 'Azadirachta Indica (Neem)'),
#  (4, 'Basella Alba (Basale)'),
#  (5, 'Brassica Juncea (Indian Mustard)'),
#  (6, 'Carissa Carandas (Karanda)'),
#  (7, 'Citrus Limon (Lemon)'),
#  (8, 'Ficus Auriculata (Roxburgh fig)'),
#  (9, 'Ficus Religiosa (Peepal Tree)'),
#  (10, 'Hibiscus Rosa-sinensis'),
#  (11, 'Jasminum (Jasmine)'),
#  (12, 'Mangifera Indica (Mango)'),
#  (13, 'Mentha (Mint)'),
#  (14, 'Moringa Oleifera (Drumstick)'),
#  (15, 'Muntingia Calabura (Jamaica Cherry-Gasagase)'),
#  (16, 'Murraya Koenigii (Curry)'),
#  (17, 'Nerium Oleander (Oleander)'),
#  (18, 'Nyctanthes Arbor-tristis (Parijata)'),
#  (19, 'Ocimum Tenuiflorum (Tulsi)'),
#  (20, 'Piper Betle (Betel)'),
#  (21, 'Plectranthus Amboinicus (Mexican Mint)'),
#  (22, 'Pongamia Pinnata (Indian Beech)'),
#  (23, 'Psidium Guajava (Guava)'),
#  (24, 'Punica Granatum (Pomegranate)'),
#  (25, 'Santalum Album (Sandalwood)'),
#  (26, 'Syzygium Cumini (Jamun)'),
#  (27, 'Syzygium Jambos (Rose Apple)'),
#  (28, 'Tabernaemontana Divaricata (Crape Jasmine)'),
#  (29, 'Trigonella Foenum-graecum (Fenugreek)')]

# %%
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters())

# %%
for p in optimizer.param_groups[0]['params']:
    if p.requires_grad:
        print(p.shape)
# Out:
# torch.Size([256, 2048])
# torch.Size([256])
# torch.Size([30, 256])
# torch.Size([30])

# %%
def train(model,
          criterion,
          optimizer,
          train_loader,
          valid_loader,
          save_file_name,
          max_epochs_stop=3,
          n_epochs=20,
          print_every=1):
    """Train a PyTorch Model

    Params
    --------
        model (PyTorch model): cnn to train
        criterion (PyTorch loss): objective to minimize
        optimizer (PyTorch optimizier): optimizer to compute gradients of model parameters
        train_loader (PyTorch dataloader): training dataloader to iterate through
        valid_loader (PyTorch dataloader): validation dataloader used for early stopping
        save_file_name (str ending in '.pt'): file path to save the model state dict
        max_epochs_stop (int): maximum number of epochs with no improvement in validation loss for early stopping
        n_epochs (int): maximum number of training epochs
        print_every (int): frequency of epochs to print training stats

    Returns
    --------
        model (PyTorch model): trained cnn with best weights
        history (DataFrame): history of train and validation loss and accuracy
    """

    # Early stopping intialization
    epochs_no_improve = 0
    valid_loss_min = np.Inf

    valid_max_acc = 0
    history = []

    # Number of epochs already trained (if using loaded in model weights)
    try:
        print(f'Model has been trained for: {model.epochs} epochs.\n')
    except:
        model.epochs = 0
        print(f'Starting Training from Scratch.\n')

    overall_start = timer()

    # Main loop
    for epoch in range(n_epochs):

        # keep track of training and validation loss each epoch
        train_loss = 0.0
        valid_loss = 0.0

        train_acc = 0
        valid_acc = 0

        # Set to training
        model.train()
        start = timer()

        # Training loop
        for ii, (data, target) in enumerate(train_loader):
            # Tensors to gpu
            if train_on_gpu:
                data, target = data.cuda(), target.cuda()

            # Clear gradients
            optimizer.zero_grad()

            # Predicted outputs are log probabilities
            output = model(data)

            # Loss and backpropagation of gradients
            loss = criterion(output, target)
            loss.backward()

            # Update the parameters
            optimizer.step()

            # Track train loss by multiplying average loss by number of examples in batch
            train_loss += loss.item() * data.size(0)

            # Calculate accuracy by finding max log probability
            _, pred = torch.max(output, dim=1)
            correct_tensor = pred.eq(target.data.view_as(pred))

            # Need to convert correct tensor from int to float to average
            accuracy = torch.mean(correct_tensor.type(torch.FloatTensor))

            # Multiply average accuracy times the number of examples in batch
            train_acc += accuracy.item() * data.size(0)

            # Track training progress
            print(
                f'Epoch: {epoch}\t{100 * (ii + 1) / len(train_loader):.2f}% complete. {timer() - start:.2f} seconds elapsed in epoch.',
                end='\r')

        # After training loops ends, start validation
        else:
            model.epochs += 1

            # Don't need to keep track of gradients
            with torch.no_grad():
                # Set to evaluation mode
                model.eval()

                # Validation loop
                for data, target in valid_loader:
                    # Tensors to gpu
                    if train_on_gpu:
                        data, target = data.cuda(), target.cuda()

                    # Forward pass
                    output = model(data)

                    # Validation loss
                    loss = criterion(output, target)
                    # Multiply average loss times the number of examples in batch
                    valid_loss += loss.item() * data.size(0)

                    # Calculate validation accuracy
                    _, pred = torch.max(output, dim=1)
                    correct_tensor = pred.eq(target.data.view_as(pred))
                    accuracy = torch.mean(
                        correct_tensor.type(torch.FloatTensor))
                    # Multiply average accuracy times the number of examples
                    valid_acc += accuracy.item() * data.size(0)

                # Calculate average losses
                train_loss = train_loss / len(train_loader.dataset)
                valid_loss = valid_loss / len(valid_loader.dataset)

                # Calculate average accuracy
                train_acc = train_acc / len(train_loader.dataset)
                valid_acc = valid_acc / len(valid_loader.dataset)

                history.append([train_loss, valid_loss, train_acc, valid_acc])

                # Print training and validation results
                if (epoch + 1) % print_every == 0:
                    print(
                        f'\nEpoch: {epoch} \tTraining Loss: {train_loss:.4f}        \tValidation Loss: {valid_loss:.4f}'
                    )
                    print(
                        f'\t\tTraining Accuracy: {100 * train_acc:.2f}%\t Validation Accuracy: {100 * valid_acc:.2f}%'
                    )

                # Save the model if validation loss decreases
                if valid_loss < valid_loss_min:
                    # Save model
                    torch.save(model.state_dict(), save_file_name)
                    # Track improvement
                    epochs_no_improve = 0
                    valid_loss_min = valid_loss
                    valid_best_acc = valid_acc
                    best_epoch = epoch

                # Otherwise increment count of epochs with no improvement
                else:
                    epochs_no_improve += 1
                    # Trigger early stopping
                    if epochs_no_improve >= max_epochs_stop:
                        print(
                            f'\nEarly Stopping! Total epochs: {epoch}. Best epoch: {best_epoch} with loss: {valid_loss_min:.2f} and acc: {100 * valid_acc:.2f}%'
                        )
                        total_time = timer() - overall_start
                        print(
                            f'{total_time:.2f} total seconds elapsed. {total_time / (epoch+1):.2f} seconds per epoch.'
                        )

                        # Load the best state dict
                        model.load_state_dict(torch.load(save_file_name))

                        # Attach the optimizer
                        model.optimizer = optimizer

                        # Format history
                        history = pd.DataFrame(
                            history,
                            columns=[
                                'train_loss', 'valid_loss', 'train_acc',
                                'valid_acc'
                            ])
                        return model, history

    # Attach the optimizer
    model.optimizer = optimizer
    # Record overall time and print out stats
    total_time = timer() - overall_start
    print(
        f'\nBest epoch: {best_epoch} with loss: {valid_loss_min:.2f} and acc: {100 * valid_acc:.2f}%'
    )
    print(
        f'{total_time:.2f} total seconds elapsed. {total_time / (epoch):.2f} seconds per epoch.'
    )
    # Format history
    history = pd.DataFrame(
        history,
        columns=['train_loss', 'valid_loss', 'train_acc', 'valid_acc'])
    return model, history

# %%
model, history = train(
    model,
    criterion,
    optimizer,
    dataloaders['train'],
    dataloaders['val'],
    save_file_name=save_file_name,
    max_epochs_stop=3,
    n_epochs=100,
    print_every=1)
# Out:
# Starting Training from Scratch.
#
#
# Epoch: 0 	Training Loss: 3.3472        	Validation Loss: 3.3028
# 		Training Accuracy: 7.90%	 Validation Accuracy: 6.81%
#
# Epoch: 1 	Training Loss: 3.0198        	Validation Loss: 3.1438
# 		Training Accuracy: 18.98%	 Validation Accuracy: 14.71%
#
# Epoch: 2 	Training Loss: 2.7009        	Validation Loss: 2.8969
# 		Training Accuracy: 35.15%	 Validation Accuracy: 41.14%
#
# Epoch: 3 	Training Loss: 2.3836        	Validation Loss: 2.5686
# 		Training Accuracy: 55.59%	 Validation Accuracy: 57.77%
#
# Epoch: 4 	Training Loss: 2.1020        	Validation Loss: 2.2123
# 		Training Accuracy: 65.40%	 Validation Accuracy: 68.94%
#
# Epoch: 5 	Training Loss: 1.7827        	Validation Loss: 1.8538
# 		Training Accuracy: 73.66%	 Validation Accuracy: 77.38%
#
# Epoch: 6 	Training Loss: 1.5258        	Validation Loss: 1.5290
# 		Training Accuracy: 80.84%	 Validation Accuracy: 84.20%
#
# Epoch: 7 	Training Loss: 1.2813        	Validation Loss: 1.2634
# 		Training Accuracy: 82.20%	 Validation Accuracy: 89.10%
#
# Epoch: 8 	Training Loss: 1.0781        	Validation Loss: 1.0611
# 		Training Accuracy: 87.28%	 Validation Accuracy: 90.74%
#
# Epoch: 9 	Training Loss: 0.9247        	Validation Loss: 0.8832
# 		Training Accuracy: 87.65%	 Validation Accuracy: 91.28%
#
# Epoch: 10 	Training Loss: 0.7866        	Validation Loss: 0.7409
# 		Training Accuracy: 90.28%	 Validation Accuracy: 91.28%
#
# Epoch: 11 	Training Loss: 0.6546        	Validation Loss: 0.6399
# 		Training Accuracy: 91.28%	 Validation Accuracy: 91.28%
#
# Epoch: 12 	Training Loss: 0.5798        	Validation Loss: 0.5610
# 		Training Accuracy: 93.01%	 Validation Accuracy: 94.01%
#
# Epoch: 13 	Training Loss: 0.4891        	Validation Loss: 0.5047
# 		Training Accuracy: 94.01%	 Validation Accuracy: 93.19%
#
# Epoch: 14 	Training Loss: 0.4551        	Validation Loss: 0.4626
# 		Training Accuracy: 94.10%	 Validation Accuracy: 93.19%
#
# Epoch: 15 	Training Loss: 0.3787        	Validation Loss: 0.4154
# 		Training Accuracy: 94.91%	 Validation Accuracy: 92.92%
#
# Epoch: 16 	Training Loss: 0.3464        	Validation Loss: 0.3781
# 		Training Accuracy: 95.19%	 Validation Accuracy: 94.01%
#
# Epoch: 17 	Training Loss: 0.3038        	Validation Loss: 0.3519
# 		Training Accuracy: 96.09%	 Validation Accuracy: 94.01%
#
# Epoch: 18 	Training Loss: 0.2975        	Validation Loss: 0.3252
# 		Training Accuracy: 95.10%	 Validation Accuracy: 95.10%
#
# Epoch: 19 	Training Loss: 0.2830        	Validation Loss: 0.2969
# 		Training Accuracy: 95.64%	 Validation Accuracy: 95.64%
#
# Epoch: 20 	Training Loss: 0.2501        	Validation Loss: 0.2791
# 		Training Accuracy: 96.55%	 Validation Accuracy: 95.37%
#
# Epoch: 21 	Training Loss: 0.2272        	Validation Loss: 0.2546
# 		Training Accuracy: 96.82%	 Validation Accuracy: 95.91%
#
# Epoch: 22 	Training Loss: 0.1933        	Validation Loss: 0.2391
# 		Training Accuracy: 96.73%	 Validation Accuracy: 95.91%
#
# Epoch: 23 	Training Loss: 0.1974        	Validation Loss: 0.2309
# 		Training Accuracy: 97.64%	 Validation Accuracy: 95.91%
#
# Epoch: 24 	Training Loss: 0.1835        	Validation Loss: 0.2302
# 		Training Accuracy: 97.91%	 Validation Accuracy: 95.91%
#
# Epoch: 25 	Training Loss: 0.1862        	Validation Loss: 0.2293
# 		Training Accuracy: 97.18%	 Validation Accuracy: 96.19%
#
# Epoch: 26 	Training Loss: 0.1638        	Validation Loss: 0.2134
# 		Training Accuracy: 97.73%	 Validation Accuracy: 95.91%
#
# Epoch: 27 	Training Loss: 0.1623        	Validation Loss: 0.1952
# 		Training Accuracy: 97.73%	 Validation Accuracy: 96.46%
#
# Epoch: 28 	Training Loss: 0.1517        	Validation Loss: 0.1881
# 		Training Accuracy: 97.64%	 Validation Accuracy: 96.19%
#
# Epoch: 29 	Training Loss: 0.1410        	Validation Loss: 0.1824
# 		Training Accuracy: 98.00%	 Validation Accuracy: 96.73%
#
# Epoch: 30 	Training Loss: 0.1357        	Validation Loss: 0.1803
# 		Training Accuracy: 98.73%	 Validation Accuracy: 96.46%
#
# Epoch: 31 	Training Loss: 0.1254        	Validation Loss: 0.1777
# 		Training Accuracy: 98.37%	 Validation Accuracy: 96.46%
#
# Epoch: 32 	Training Loss: 0.1215        	Validation Loss: 0.1744
# 		Training Accuracy: 98.55%	 Validation Accuracy: 96.46%
#
# Epoch: 33 	Training Loss: 0.1157        	Validation Loss: 0.1710
# 		Training Accuracy: 98.00%	 Validation Accuracy: 96.73%
#
# Epoch: 34 	Training Loss: 0.1201        	Validation Loss: 0.1632
# 		Training Accuracy: 98.37%	 Validation Accuracy: 96.19%
#
# Epoch: 35 	Training Loss: 0.1063        	Validation Loss: 0.1622
# 		Training Accuracy: 98.46%	 Validation Accuracy: 95.91%
#
# Epoch: 36 	Training Loss: 0.1085        	Validation Loss: 0.1614
# 		Training Accuracy: 98.82%	 Validation Accuracy: 96.19%
#
# Epoch: 37 	Training Loss: 0.1044        	Validation Loss: 0.1585
# 		Training Accuracy: 98.37%	 Validation Accuracy: 97.00%
#
# Epoch: 38 	Training Loss: 0.0947        	Validation Loss: 0.1504
# 		Training Accuracy: 98.91%	 Validation Accuracy: 97.00%
#
# Epoch: 39 	Training Loss: 0.0990        	Validation Loss: 0.1413
# 		Training Accuracy: 98.64%	 Validation Accuracy: 97.28%
#
# Epoch: 40 	Training Loss: 0.0915        	Validation Loss: 0.1380
# 		Training Accuracy: 98.64%	 Validation Accuracy: 97.00%
#
# Epoch: 41 	Training Loss: 0.0923        	Validation Loss: 0.1342
# 		Training Accuracy: 99.00%	 Validation Accuracy: 97.28%
#
# Epoch: 42 	Training Loss: 0.0817        	Validation Loss: 0.1389
# 		Training Accuracy: 99.27%	 Validation Accuracy: 97.00%
#
# Epoch: 43 	Training Loss: 0.0822        	Validation Loss: 0.1397
# 		Training Accuracy: 99.46%	 Validation Accuracy: 97.00%
#
# Epoch: 44 	Training Loss: 0.0725        	Validation Loss: 0.1323
# 		Training Accuracy: 99.36%	 Validation Accuracy: 96.73%
#
# Epoch: 45 	Training Loss: 0.0851        	Validation Loss: 0.1229
# 		Training Accuracy: 98.82%	 Validation Accuracy: 97.00%
#
# Epoch: 46 	Training Loss: 0.0717        	Validation Loss: 0.1199
# 		Training Accuracy: 99.09%	 Validation Accuracy: 97.00%
#
# Epoch: 47 	Training Loss: 0.0808        	Validation Loss: 0.1214
# 		Training Accuracy: 98.91%	 Validation Accuracy: 97.55%
#
# Epoch: 48 	Training Loss: 0.0723        	Validation Loss: 0.1179
# 		Training Accuracy: 99.18%	 Validation Accuracy: 97.82%
#
# Epoch: 49 	Training Loss: 0.0701        	Validation Loss: 0.1174
# 		Training Accuracy: 99.55%	 Validation Accuracy: 97.00%
#
# Epoch: 50 	Training Loss: 0.0670        	Validation Loss: 0.1258
# 		Training Accuracy: 99.36%	 Validation Accuracy: 96.46%
#
# Epoch: 51 	Training Loss: 0.0571        	Validation Loss: 0.1324
# 		Training Accuracy: 99.64%	 Validation Accuracy: 96.46%
#
# Epoch: 52 	Training Loss: 0.0618        	Validation Loss: 0.1295
# 		Training Accuracy: 99.00%	 Validation Accuracy: 96.46%
#
# Early Stopping! Total epochs: 52. Best epoch: 49 with loss: 0.12 and acc: 96.46%
# 1966.99 total seconds elapsed. 37.11 seconds per epoch.

# %% [markdown]
# # **Results**

# %%
plt.figure(figsize=(8, 6))
for c in ['train_loss', 'valid_loss']:
    plt.plot(
        history[c], label=c)
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Average Negative Log Likelihood')
plt.title('Training and Validation Losses')
# Out:
# Text(0.5, 1.0, 'Training and Validation Losses')

# %%
plt.figure(figsize = (8, 6))

for c in ['train_acc', 'valid_acc']:
    plt.plot(100 * history[c], label = c)

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Average Accuracy')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %% [markdown]
# # **Save Model**

# %%
def save_checkpoint(model, path):

    """Save a PyTorch model checkpoint

    Params
    --------
        model (PyTorch model): model to save
        path (str): location to save model. Must start with `model_name-` and end in '.pth'

    Returns
    --------
        None, save the `model` to `path`

    """

    model_name = path.split('-')[0]
    assert (model_name in ['vgg16', 'resnet50'
                           ]), "Path must have the correct model name"

    # Basic details
    checkpoint = {
        'class_to_idx': model.class_to_idx,
        'idx_to_class': model.idx_to_class,
        'epochs': model.epochs,
    }

    # Extract the final classifier and the state dictionary

    if model_name == 'vgg16':

        # Check to see if model was parallelized
        if multi_gpu:
            checkpoint['classifier'] = model.module.classifier
            checkpoint['state_dict'] = model.module.state_dict()
        else:
            checkpoint['classifier'] = model.classifier
            checkpoint['state_dict'] = model.state_dict()

    elif model_name == 'resnet50':
        if multi_gpu:
            checkpoint['fc'] = model.module.fc
            checkpoint['state_dict'] = model.module.state_dict()
        else:
            checkpoint['fc'] = model.fc
            checkpoint['state_dict'] = model.state_dict()

    # Add the optimizer
    checkpoint['optimizer'] = model.optimizer
    checkpoint['optimizer_state_dict'] = model.optimizer.state_dict()

    # Save the data to the path
    torch.save(checkpoint, path)

# %%
save_checkpoint(model, path=checkpoint_path)

# %% [markdown]
# # **Loading Checkpoints**

# %%
def load_checkpoint(path):

    """Load a PyTorch model checkpoint

    Params
    --------
        path (str): saved model checkpoint. Must start with `model_name-` and end in '.pth'

    Returns
    --------
        None, save the `model` to `path`

    """

    # Get the model name
    model_name = path.split('-')[0]
    assert (model_name in ['vgg16', 'resnet50'
                           ]), "Path must have the correct model name"

    # Load in checkpoint
    checkpoint = torch.load(path)

    if model_name == 'vgg16':
        model = models.vgg16(weights = 'DEFAULT')
        # Make sure to set parameters as not trainable
        for param in model.parameters():
            param.requires_grad = False
        model.classifier = checkpoint['classifier']

    elif model_name == 'resnet50':
        model = models.resnet50(weights = 'DEFAULT')
        # Make sure to set parameters as not trainable
        for param in model.parameters():
            param.requires_grad = False
        model.fc = checkpoint['fc']

    # Load in the state dict
    model.load_state_dict(checkpoint['state_dict'])

    total_params = sum(p.numel() for p in model.parameters())
    print(f'{total_params:,} total parameters.')
    total_trainable_params = sum(
        p.numel() for p in model.parameters() if p.requires_grad)
    print(f'{total_trainable_params:,} total gradient parameters.')

    # Move to gpu
    if multi_gpu:
        model = nn.DataParallel(model)

    if train_on_gpu:
        model = model.to('cuda')

    # Model basics
    model.class_to_idx = checkpoint['class_to_idx']
    model.idx_to_class = checkpoint['idx_to_class']
    model.epochs = checkpoint['epochs']

    # Optimizer
    optimizer = checkpoint['optimizer']
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

    return model, optimizer

# %%
model, optimizer = load_checkpoint(path=checkpoint_path)
# Out:
# 24,040,286 total parameters.
# 532,254 total gradient parameters.

# %% [markdown]
# # **Inference**

# %%
def process_image(image_path):
    """Process an image path into a PyTorch tensor"""

    image = Image.open(image_path)
    # Resize
    img = image.resize((256, 256))

    # Center crop
    width = 256
    height = 256
    new_width = 224
    new_height = 224

    left = (width - new_width) / 2
    top = (height - new_height) / 2
    right = (width + new_width) / 2
    bottom = (height + new_height) / 2
    img = img.crop((left, top, right, bottom))

    # Convert to numpy, transpose color dimension and normalize
    img = np.array(img).transpose((2, 0, 1)) / 256

    # Standardization
    means = np.array([0.485, 0.456, 0.406]).reshape((3, 1, 1))
    stds = np.array([0.229, 0.224, 0.225]).reshape((3, 1, 1))

    img = img - means
    img = img / stds

    img_tensor = torch.Tensor(img)

    return img_tensor

# %%
def predict(image_path, model, topk=5):
    """Make a prediction for an image using a trained model

    Params
    --------
        image_path (str): filename of the image
        model (PyTorch model): trained model for inference
        topk (int): number of top predictions to return

    Returns

    """
    real_class = image_path.split('/')[-2]

    # Convert to pytorch tensor
    img_tensor = process_image(image_path)

    # Resize
    if train_on_gpu:
        img_tensor = img_tensor.view(1, 3, 224, 224).cuda()
    else:
        img_tensor = img_tensor.view(1, 3, 224, 224)

    # Set to evaluation
    with torch.no_grad():
        model.eval()
        # Model outputs log probabilities
        out = model(img_tensor)
        ps = torch.exp(out)

        # Find the topk predictions
        topk, topclass = ps.topk(topk, dim=1)

        # Extract the actual classes and probabilities
        top_classes = [
            model.idx_to_class[class_] for class_ in topclass.cpu().numpy()[0]
        ]
        top_p = topk.cpu().numpy()[0]

        return img_tensor.cpu().squeeze(), top_p, top_classes, real_class

# %%
np.random.seed = 100


def random_test_image():
    """Pick a random test image from the test directory"""
    c = np.random.choice(categories)
    root = testdir +"/"+ c + '/'
    img_path = root + np.random.choice(os.listdir(root))
    return img_path


_ = imshow_tensor(process_image(random_test_image()))

# %%
img, top_p, top_classes, real_class = predict(random_test_image(), model,topk=2)

# %%
top_p, top_classes, real_class
# Out:
# (array([0.96075064, 0.01700847], dtype=float32),
#  ['Alpinia Galanga (Rasna)', 'Murraya Koenigii (Curry)'],
#  'Alpinia Galanga (Rasna)')

# %%
top_p
# Out:
# array([0.96075064, 0.01700847], dtype=float32)

# %% [markdown]
# ## **Display Preds**

# %%
def display_prediction(image_path, model, topk):
    """Display image and preditions from model"""

    # Get predictions
    img, ps, classes, y_obs = predict(image_path, model, topk)
    # Convert results to dataframe for plotting
    result = pd.DataFrame({'p': ps}, index=classes)

    # Show the image
    plt.figure(figsize=(16, 5))
    ax = plt.subplot(1, 2, 1)
    ax, img = imshow_tensor(img, ax=ax)

    # Set title to be the actual class
    ax.set_title(y_obs, size=20)

    ax = plt.subplot(1, 2, 2)
    # Plot a bar plot of predictions
    result.sort_values('p')['p'].plot.barh(color='blue', edgecolor='k', ax=ax)
    plt.xlabel('Predicted Probability')
    plt.tight_layout()

# %%
display_prediction(random_test_image(), model, topk=3)

# %% [markdown]
# # **Testing Accuracy**

# %%
def k_accuracy(output, target, topk=(1, )):
    """Compute the topk accuracy(s)"""
    if train_on_gpu:
        output = output.to('cuda')
        target = target.to('cuda')

    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        # Find the predicted classes and transpose
        _, pred = output.topk(k=maxk, dim=1, largest=True, sorted=True)
        pred = pred.t()

        # Determine predictions equal to the targets
        correct = pred.eq(target.reshape(1, -1).expand_as(pred))

        res = []

        # For each k, find the percentage of correct
        for k in topk:

            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)

            # Precision: TP / (TP + FP)
            precision = correct_k / maxk

            # Recall: TP / (TP + FN)
            recall = correct_k / target.sum()

            # F1-score: 2 * (precision * recall) / (precision + recall)
            f1 = 2 * (precision * recall) / (precision + recall)

            res.append((correct_k.mul_(100.0 / batch_size).item(), precision.item(), recall.item(), f1.item()))


        return res

# %%
testiter = iter(dataloaders['test'])
# Get a batch of testing images and labels
features, targets = next(testiter)

if train_on_gpu:
    res = k_accuracy(model(features.to('cuda')), targets, topk=(1, 5))
else:
    res = k_accuracy(model(features), targets, topk=(1, 5))

print(res)
print("first tuple is top 1 and other is top 5, of accuracy, precicion, recall and F1 scores respectively")
# Out:
# [(98.36511993408203, 72.20000457763672, 0.0725628137588501, 0.14497992396354675), (100.0, 73.4000015258789, 0.07376884669065475, 0.14738956093788147)]
# first tuple is top 1 and other is top 5, of accuracy, precicion, recall and F1 scores respectively

# %%
def accuracy(output, target, topk=(1, )):
    """Compute the topk accuracy(s)"""
    if train_on_gpu:
        output = output.to('cuda')
        target = target.to('cuda')

    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        # Find the predicted classes and transpose
        _, pred = output.topk(k=maxk, dim=1, largest=True, sorted=True)
        pred = pred.t()

        # Determine predictions equal to the targets
        correct = pred.eq(target.reshape(1, -1).expand_as(pred))

        res = []

        # For each k, find the percentage of correct
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size).item())
        return res

# %% [markdown]
# ## **Function to Evaluate Model Over All Classes**

# %%
def evaluate(model, test_loader, criterion, topk=(1, 3, 5)):
    """Measure the performance of a trained PyTorch model

    Params
    --------
        model (PyTorch model): trained cnn for inference
        test_loader (PyTorch DataLoader): test dataloader
        topk (tuple of ints): accuracy to measure

    Returns
    --------
        results (DataFrame): results for each category

    """
    confusion_matrix = torch.zeros(n_classes, n_classes)
    classes = []
    losses = []
    # Hold accuracy results
    acc_results = np.zeros((len(test_loader.dataset), len(topk)))
    i = 0

    model.eval()
    with torch.no_grad():

        # Testing loop
        for data, targets in test_loader:

            # Tensors to gpu
            if train_on_gpu:
                data, targets = data.to('cuda'), targets.to('cuda')

            # Raw model output
            out = model(data)
            _, predscm = torch.max(out, 1)
            for t, p in zip(targets.view(-1), predscm.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

            # Iterate through each example
            for pred, true in zip(out, targets):
                # Find topk accuracy
                acc_results[i, :] = accuracy(
                    pred.unsqueeze(0), true.unsqueeze(0), topk)
                classes.append(model.idx_to_class[true.item()])
                # Calculate the loss
                loss = criterion(pred.view(1, n_classes), true.view(1))
                losses.append(loss.item())
                i += 1

    # Send results to a dataframe and calculate average across classes
    results = pd.DataFrame(acc_results, columns=[f'top{i}' for i in topk])
    results['class'] = classes
    results['loss'] = losses
    results = results.groupby(classes).mean()

    return results.reset_index().rename(columns={'index': 'class'}),confusion_matrix

criterion = nn.NLLLoss()
# Evaluate the model on all the training data
results,confusion_matrix = evaluate(model, dataloaders['test'], criterion)

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.0f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig(f'outputs/confusion_matrix.png')
    return plt

# %%
classnames = [model.idx_to_class[i] for i in range(0,n_classes)]

# %%
plt.figure(figsize=(20,20))
plt = plot_confusion_matrix(confusion_matrix, classnames)
# Out:
# Confusion matrix, without normalization

# %%
def cm_as_dataframe(cm):
    cm = pd.DataFrame(cm)
    cm.columns = classnames
    cm.index = classnames
    cm = cm.reset_index()
    return cm

cm_as_dataframe(confusion_matrix.cpu().numpy()).to_csv(f'outputs/confmat.csv',index=None)

# %%
print(f"Overall Accuracy:{confusion_matrix.diag().sum()/confusion_matrix.sum()}")
# Out:
# Overall Accuracy:0.9836512207984924

# %%
results = results.merge(cnt_df,left_on='class',right_on='cat')

# %%
results
# Out:
#                                            class        top1   top3   top5  \
# 0                        Alpinia Galanga (Rasna)  100.000000  100.0  100.0
# 1               Amaranthus Viridis (Arive-Dantu)   95.833333  100.0  100.0
# 2           Artocarpus Heterophyllus (Jackfruit)  100.000000  100.0  100.0
# 3                      Azadirachta Indica (Neem)  100.000000  100.0  100.0
# 4                          Basella Alba (Basale)  100.000000  100.0  100.0
# 5               Brassica Juncea (Indian Mustard)  100.000000  100.0  100.0
# 6                     Carissa Carandas (Karanda)  100.000000  100.0  100.0
# 7                           Citrus Limon (Lemon)  100.000000  100.0  100.0
# 8                Ficus Auriculata (Roxburgh fig)   70.000000   90.0  100.0
# 9                  Ficus Religiosa (Peepal Tree)  100.000000  100.0  100.0
# 10                        Hibiscus Rosa-sinensis   87.500000  100.0  100.0
# 11                            Jasminum (Jasmine)  100.000000  100.0  100.0
# 12                      Mangifera Indica (Mango)  100.000000  100.0  100.0
# 13                                 Mentha (Mint)  100.000000  100.0  100.0
# 14                  Moringa Oleifera (Drumstick)  100.000000  100.0  100.0
# 15  Muntingia Calabura (Jamaica Cherry-Gasagase)  100.000000  100.0  100.0
# 16                      Murraya Koenigii (Curry)  100.000000  100.0  100.0
# 17                    Nerium Oleander (Oleander)  100.000000  100.0  100.0
# 18           Nyctanthes Arbor-tristis (Parijata)  100.000000  100.0  100.0
# 19                    Ocimum Tenuiflorum (Tulsi)  100.000000  100.0  100.0
# 20                           Piper Betle (Betel)   88.888889  100.0  100.0
# 21        Plectranthus Amboinicus (Mexican Mint)  100.000000  100.0  100.0
# 22               Pongamia Pinnata (Indian Beech)  100.000000  100.0  100.0
# 23                       Psidium Guajava (Guava)  100.000000  100.0  100.0
# 24                 Punica Granatum (Pomegranate)  100.000000  100.0  100.0
# 25                   Santalum Album (Sandalwood)  100.000000  100.0  100.0
# 26                       Syzygium Cumini (Jamun)  100.000000  100.0  100.0
# 27                  Syzygium Jambos (Rose Apple)  100.000000  100.0  100.0
# 28    Tabernaemontana Divaricata (Crape Jasmine)  100.000000  100.0  100.0
# 29         Trigonella Foenum-graecum (Fenugreek)  100.000000  100.0  100.0
#
#         loss                                           cat  train_cnt  \
# 0   0.059931                       Alpinia Galanga (Rasna)         30
# 1   0.164561              Amaranthus Viridis (Arive-Dantu)         73
# 2   0.128459          Artocarpus Heterophyllus (Jackfruit)         33
# 3   0.062982                     Azadirachta Indica (Neem)         36
# 4   0.011859                         Basella Alba (Basale)         62
# 5   0.033613              Brassica Juncea (Indian Mustard)         20
# 6   0.052912                    Carissa Carandas (Karanda)         44
# 7   0.099244                          Citrus Limon (Lemon)         34
# 8   0.596706               Ficus Auriculata (Roxburgh fig)         30
# 9   0.038566                 Ficus Religiosa (Peepal Tree)         38
# 10  0.251173                        Hibiscus Rosa-sinensis         26
# 11  0.026947                            Jasminum (Jasmine)         43
# 12  0.009836                      Mangifera Indica (Mango)         37
# 13  0.028614                                 Mentha (Mint)         58
# 14  0.015911                  Moringa Oleifera (Drumstick)         46
# 15  0.017698  Muntingia Calabura (Jamaica Cherry-Gasagase)         34
# 16  0.067181                      Murraya Koenigii (Curry)         36
# 17  0.054815                    Nerium Oleander (Oleander)         37
# 18  0.115204           Nyctanthes Arbor-tristis (Parijata)         24
# 19  0.193026                    Ocimum Tenuiflorum (Tulsi)         31
# 20  0.192471                           Piper Betle (Betel)         29
# 21  0.215510        Plectranthus Amboinicus (Mexican Mint)         29
# 22  0.038283               Pongamia Pinnata (Indian Beech)         37
# 23  0.009690                       Psidium Guajava (Guava)         39
# 24  0.045027                 Punica Granatum (Pomegranate)         47
# 25  0.072884                   Santalum Album (Sandalwood)         35
# 26  0.017512                       Syzygium Cumini (Jamun)         23
# 27  0.023858                  Syzygium Jambos (Rose Apple)         34
# 28  0.118252    Tabernaemontana Divaricata (Crape Jasmine)         34
# 29  0.113833         Trigonella Foenum-graecum (Fenugreek)         22
#
#     val_cnt  test_cnt
# 0        10        10
# 1        25        24
# 2        11        12
# 3        12        12
# 4        21        20
# 5         7         7
# 6        15        15
# 7        11        12
# 8        10        10
# 9        12        13
# 10        9         8
# 11       14        14
# 12       12        13
# 13       20        19
# 14       15        16
# 15       11        11
# 16       12        12
# 17       12        13
# 18        8         8
# 19       11        10
# 20       10         9
# 21       10         9
# 22       12        12
# 23       13        13
# 24       16        16
# 25       11        12
# 26        8         8
# 27       11        11
# 28       11        11
# 29        7         7

# %%
results.to_csv(f'outputs/test_accuracy.csv',index=None)

# %% [markdown]
# **check category**

# %%
def display_category(model, category, n=4):
    """Display predictions for a category
    """
    category_results = results.loc[results['class'] == category]
    #print(category_results.iloc[:, :10], '/n')

    images = np.random.choice(
        os.listdir(testdir + "/"+category + '/'), size=n, replace=False)

    for img in images:
        display_prediction(testdir +"/"+ category + '/' + img, model, 5)

# %%
display_category(model, 'Alpinia Galanga (Rasna)', n = 3 )

# %% [markdown]
# ## **Test Time Augmentation**

# %%
# Image transformations
tta_random_image_transforms = transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.ColorJitter(),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),  # Image net standards
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])  # Imagenet standards
    ])

# %%
# Datasets from folders
ttadata = {
    'test':
    datasets.ImageFolder(root=testdir, transform=tta_random_image_transforms)
}

# Dataloader iterators
ttadataloader = {
    'test': DataLoader(ttadata['test'], batch_size=512, shuffle=False,num_workers=0)
}

# %%
def tta_preds_n_averaged(model, test_loader,n=5):
    """
    Returns the TTA preds from a trained PyTorch model

    Params
    --------
        model (PyTorch model): trained cnn for inference
        test_loader (PyTorch DataLoader): test dataloader

    Returns
    --------
        results (array): results for each category
    """

    # Hold results
    results = np.zeros((len(test_loader.dataset), n_classes))
    bs = test_loader.batch_size
    model.eval()
    with torch.no_grad():
        #aug loop:
        for _ in range(n):
            # Testing loop
            tmp_pred = np.zeros((len(test_loader.dataset), n_classes))
            for i,(data, targets) in enumerate(tqdm.tqdm(test_loader)):

                # Tensors to gpu
                if train_on_gpu:
                    data, targets = data.to('cuda'), targets.to('cuda')

                # Raw model output
                out = model(data)
                tmp_pred[i*bs:(i+1)*bs] = np.array(out.cpu())

            results+=tmp_pred
    return results/n

# %%
preds_tta = tta_preds_n_averaged(model, ttadataloader['test'])
# Out:
# 100%|██████████| 1/1 [00:09<00:00,  9.85s/it]
# 100%|██████████| 1/1 [00:09<00:00,  9.07s/it]
# 100%|██████████| 1/1 [00:07<00:00,  7.90s/it]
# 100%|██████████| 1/1 [00:09<00:00,  9.48s/it]
# 100%|██████████| 1/1 [00:08<00:00,  8.34s/it]

# %%
preds_tta_index = np.argmax(preds_tta,axis=1)
print(f"TTA Accuracy: {sum(ttadata['test'].targets==preds_tta_index)/len(preds_tta_index)}")
# Out:
# TTA Accuracy: 0.9918256130790191

# %%
preddf = pd.DataFrame({'ttapreds':preds_tta_index,'truelabel':ttadata['test'].targets})
preddf['tta_acc'] = preddf['ttapreds'] == preddf['truelabel']
preddf['class'] = preddf['truelabel'].apply(lambda x: idx_to_class[x])
category_tta= preddf.groupby(['class']).aggregate({'tta_acc':np.mean}).reset_index()

# %%
ttaresults = results.merge(category_tta,on='class',how='left')[['class','top1','tta_acc', 'train_cnt', 'val_cnt',
       'test_cnt']]

# %%
ttaresults.columns = ['class', 'normal_acc', 'tta_acc', 'train_cnt', 'val_cnt', 'test_cnt']

# %%
ttaresults['tta_acc']*=100

# %%
ttaresults
# Out:
#                                            class  normal_acc  tta_acc  \
# 0                        Alpinia Galanga (Rasna)  100.000000    100.0
# 1               Amaranthus Viridis (Arive-Dantu)   95.833333    100.0
# 2           Artocarpus Heterophyllus (Jackfruit)  100.000000    100.0
# 3                      Azadirachta Indica (Neem)  100.000000    100.0
# 4                          Basella Alba (Basale)  100.000000    100.0
# 5               Brassica Juncea (Indian Mustard)  100.000000    100.0
# 6                     Carissa Carandas (Karanda)  100.000000    100.0
# 7                           Citrus Limon (Lemon)  100.000000    100.0
# 8                Ficus Auriculata (Roxburgh fig)   70.000000     70.0
# 9                  Ficus Religiosa (Peepal Tree)  100.000000    100.0
# 10                        Hibiscus Rosa-sinensis   87.500000    100.0
# 11                            Jasminum (Jasmine)  100.000000    100.0
# 12                      Mangifera Indica (Mango)  100.000000    100.0
# 13                                 Mentha (Mint)  100.000000    100.0
# 14                  Moringa Oleifera (Drumstick)  100.000000    100.0
# 15  Muntingia Calabura (Jamaica Cherry-Gasagase)  100.000000    100.0
# 16                      Murraya Koenigii (Curry)  100.000000    100.0
# 17                    Nerium Oleander (Oleander)  100.000000    100.0
# 18           Nyctanthes Arbor-tristis (Parijata)  100.000000    100.0
# 19                    Ocimum Tenuiflorum (Tulsi)  100.000000    100.0
# 20                           Piper Betle (Betel)   88.888889    100.0
# 21        Plectranthus Amboinicus (Mexican Mint)  100.000000    100.0
# 22               Pongamia Pinnata (Indian Beech)  100.000000    100.0
# 23                       Psidium Guajava (Guava)  100.000000    100.0
# 24                 Punica Granatum (Pomegranate)  100.000000    100.0
# 25                   Santalum Album (Sandalwood)  100.000000    100.0
# 26                       Syzygium Cumini (Jamun)  100.000000    100.0
# 27                  Syzygium Jambos (Rose Apple)  100.000000    100.0
# 28    Tabernaemontana Divaricata (Crape Jasmine)  100.000000    100.0
# 29         Trigonella Foenum-graecum (Fenugreek)  100.000000    100.0
#
#     train_cnt  val_cnt  test_cnt
# 0          30       10        10
# 1          73       25        24
# 2          33       11        12
# 3          36       12        12
# 4          62       21        20
# 5          20        7         7
# 6          44       15        15
# 7          34       11        12
# 8          30       10        10
# 9          38       12        13
# 10         26        9         8
# 11         43       14        14
# 12         37       12        13
# 13         58       20        19
# 14         46       15        16
# 15         34       11        11
# 16         36       12        12
# 17         37       12        13
# 18         24        8         8
# 19         31       11        10
# 20         29       10         9
# 21         29       10         9
# 22         37       12        12
# 23         39       13        13
# 24         47       16        16
# 25         35       11        12
# 26         23        8         8
# 27         34       11        11
# 28         34       11        11
# 29         22        7         7

# %% [markdown]
# ### **TFLITE**

# %%
# !pip install onnx
# !pip install tf2onnx
# !pip install onnx_tf

# %% [markdown]
# ## Converting the model to TFlite

# %%
import onnx_tf

# Load the PyTorch ResNet50 model

path = '/content/resnet50-transfer.pth'
# Get the model name

checkpoint = torch.load(path, map_location = torch.device('cpu'))

model = models.resnet50( weights = None )

model.fc = checkpoint['fc']

# Load in the state dict
model.load_state_dict(checkpoint['state_dict'])

# Model basics
model.class_to_idx = checkpoint['class_to_idx']
model.idx_to_class = checkpoint['idx_to_class']
model.epochs = checkpoint['epochs']

model.eval()

# Export the PyTorch model to ONNX format
input_shape = (1, 3, 224, 224)
dummy_input = torch.randn(input_shape)
onnx_model_path = 'resnet50.onnx'
torch.onnx.export(model, dummy_input, onnx_model_path,  input_names=['input'], output_names=['output'], verbose=False)

# Load the ONNX model
onnx_model = onnx.load(onnx_model_path)

# Convert the ONNX model to TensorFlow format
tf_model_path = 'resnet50.pb'
tf_rep = onnx_tf.backend.prepare(onnx_model)
tf_rep.export_graph(tf_model_path)

# Convert the TensorFlow model to TensorFlow Lite format
converter = tf.compat.v1.lite.TFLiteConverter.from_saved_model(tf_model_path)
tflite_model = converter.convert()

# Save the TensorFlow Lite model to a file
with open('resnet50.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:absl:Function `__call__` contains input name(s) x, y with unsupported characters which will be renamed to transpose_162_x, mul_1_y in the SavedModel.
# INFO:absl:Found untraced functions such as gen_tensor_dict while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:absl:Writing fingerprint to resnet50.pb/fingerprint.pb
# INFO:absl:Using experimental converter: If you encountered a problem please file a bug. You can opt-out by setting experimental_new_converter=False

# %% [markdown]
# ## Testin inference ( somehow the accuracy dropped significantly )

# %%
# Load the TFLite model (replace 'model.tflite' with your file name)
model_path = '/content/resnet50.tflite'
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Load and preprocess your image
image_path = '/content/data/test/Alpinia Galanga (Rasna)/AG-S-006.jpg'  # Replace with your image file path
image = Image.open(image_path)
image = image.resize((224, 224))  # Adjust the size as needed
image = np.array(image)
image = image / 255.0  # Normalize pixel values to [0, 1]

# Ensure the image shape matches the input shape of your model
input_data = np.expand_dims(image, axis=0).astype(np.float32)  # Add a batch dimension and cast to FLOAT32
input_data = np.transpose(input_data, (0, 3, 1, 2))
print(np.shape(input_data))

# Set the input tensor
input_details = interpreter.get_input_details()
# print(input_details)
interpreter.set_tensor(input_details[0]['index'], input_data)

# Run inference
interpreter.invoke()

# Get the output tensor details
output_details = interpreter.get_output_details()

# Get the output data (predictions)
output_data = interpreter.get_tensor(output_details[0]['index'])
logits = output_data

class_probabilities = (np.exp(logits) / np.sum(np.exp(logits), axis=1))

# Get the index of the class with the highest probability (the predicted class)
predicted_class = np.argmax(class_probabilities)

predicted_class_probability = class_probabilities[0][predicted_class]

# Process and interpret the output as needed
# print("Model predictions:", output_data)

# Get the name of the predicted class
predicted_class_name = model.idx_to_class[predicted_class]
print(f"Model predictions: {predicted_class_name} and Confidence Level : {predicted_class_probability}")

# Print the name of the predicted class
print("Predicted Class Name:", predicted_class_name)

print(class_probabilities)
# Out:
# (1, 3, 224, 224)
# [[ -0.55900216  -9.061857    -9.448008    -6.2010984   -8.376883
#    -7.942148    -6.9195175   -7.875105    -6.697874    -8.261106
#    -6.1319294   -9.457909    -3.863789    -8.112614    -5.5372047
#    -8.523358    -5.7977257   -3.0919      -7.7827806   -7.7966595
#    -5.398447    -6.112218    -8.097801   -10.08227    -10.585562
#   -10.263716    -8.4636755   -4.6079674  -10.304787    -1.1140165 ]]
# Model predictions: Alpinia Galanga (Rasna) and Confidence Level : 0.5717793703079224
# Predicted Class Name: Alpinia Galanga (Rasna)
# [[5.7177937e-01 1.1600733e-04 7.8846504e-05 2.0272026e-03 2.3012623e-04
#   3.5544205e-04 9.8830659e-04 3.8008910e-04 1.2335315e-03 2.5837318e-04
#   2.1723853e-03 7.8069686e-05 2.0988323e-02 2.9973441e-04 3.9375178e-03
#   1.9877077e-04 3.0344478e-03 4.5415577e-02 4.1685143e-04 4.1110601e-04
#   4.5236005e-03 2.2156313e-03 3.0420729e-04 4.1814405e-05 2.5278361e-05
#   3.4875859e-05 2.1099513e-04 9.9720675e-03 3.3472490e-05 3.2823795e-01]]
